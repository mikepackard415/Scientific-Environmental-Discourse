# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read in topic modeling data

# %%
env = pd.read_csv('../Data/Environmental Discourse/env_processed_text.csv', index_col=0)

# %%
env.head()
# Out:
#                                                   url  \
# 4   https://www.resilience.org/stories/2021-07-12/...
# 5   https://www.resilience.org/stories/2021-07-12/...
# 7   https://www.resilience.org/stories/2021-07-12/...
# 9   https://www.resilience.org/stories/2021-07-08/...
# 11  https://www.resilience.org/stories/2021-07-07/...
#
#                                                 title        date  \
# 4                                    The show is over  2021-07-12
# 5             The Energy Bulletin Weekly 12 July 2021  2021-07-12
# 7                           On the Existence of A Man  2021-07-12
# 9   Climate change, domination and the temporality...  2021-07-08
# 11                               Least worst politics  2021-07-07
#
#                                        text_processed
# 4   piece originally publish july tomorrow week pa...
# 5   tom whipple steve andrews editor quote week sa...
# 7   philosopher mystic time show connect human uni...
# 9   master possesor nature meaning enslave society...
# 11  part ii small farm future build argument local...

# %%
env.shape
# Out:
# (46825, 4)

# %%
env['tokens'] = env.text_processed.apply(lambda x: x.split())

# %%
env_small = env.sample(500)

# %% [markdown]
# Read in word embedding data

# %%
dfs = []
for i in range(5,22):
    j = str(i)
    k = (2 - len(j)) * '0' + j
    dfs.append(pd.read_pickle('../Data/Environmental Discourse/sent_processing/env_processed_sent_{}.pkl'.format(k)))

# %%
# Out:
# [['autism',
#   'linked',
#   'environmental',
#   'factors',
#   'research',
#   'says',
#   'new',
#   'study',
#   'looking',
#   'possible',
#   'environmental',
#   'causes',
#   'autism',
#   'neurological',
#   'disorder',
#   'affects',
#   'communication',
#   'social',
#   'interaction',
#   'abilities',
#   'demonstrates',
#   'suite',
#   'pollutants',
#   'working',
#   'combination',
#   'critically',
#   'affect',
#   'developing',
#   'embryo'],
#  ['research',
#   'focused',
#   'chemicals',
#   'found',
#   'decade',
#   'ago',
#   'brick',
#   'n.j',
#   'area',
#   'unusually',
#   'high',
#   'rate',
#   'disorder'],
#  ['federal',
#   'study',
#   'dismissed',
#   'connection',
#   'pollutants',
#   'autism',
#   'found',
#   'children',
#   'brick',
#   'residents',
#   'pressed',
#   'study',
#   'story',
#   'reached',
#   'team',
#   'scientists',
#   'decided',
#   'look',
#   'effects',
#   'contaminants',
#   'combination'],
#  ['said',
#   'carol',
#   'l.',
#   'reinisch',
#   'marine',
#   'biological',
#   'laboratory',
#   'woods',
#   'hole',
#   'mass',
#   'led',
#   'research',
#   'community',
#   'study',
#   'showed',
#   'mixture',
#   'chemicals',
#   'cause',
#   'uptick',
#   'enzyme',
#   'important',
#   'neural',
#   'development'],
#  ['john',
#   'schaeffer',
#   'started',
#   'urban',
#   'refugee',
#   'living',
#   'remote',
#   'commune',
#   'california'],
#  ['tired',
#   'life',
#   'electricity',
#   'schaeffer',
#   'tinkerer',
#   'hooked',
#   'solar',
#   'powered',
#   'television',
#   'home',
#   'finding',
#   'innovative',
#   'ways',
#   'introduce',
#   'mainstream',
#   'america',
#   'renewable_energy'],
#  ['sentient',
#   'country',
#   'familiar',
#   'story',
#   'bush',
#   'administration',
#   'warrantless',
#   'wiretaps',
#   'revealed',
#   'new_york_times'],
#  ['turns', 'nyt', 'sitting', 'story', 'election'],
#  ['thanks'],
#  ['wo', 'details', 'covered', 'extensively', 'media', 'outlets', 'blogs'],
#  ['return', 'subject', 've', 'written'],
#  ['think', 'eco', 'terrorism', 'bit', 'rhetoric', 'casual', 'turn', 'phrase'],
#  ['americablog',
#   'brings',
#   'word',
#   'pentagon',
#   'spying',
#   'campus',
#   'gay',
#   'groups',
#   'oppose',
#   'military',
#   'ask',
#   'tell',
#   'policy'],
#  ['homo', 'terrorism'],
#  ['fbi',
#   'spying',
#   'groups',
#   'active',
#   'causes',
#   'diverse',
#   'environment',
#   'animal',
#   'cruelty',
#   'poverty',
#   'relief'],
#  ['attacks',
#   'sept',
#   'john',
#   'ashcroft',
#   'attorney',
#   'general',
#   'loosened',
#   'restrictions',
#   'f.b.i',
#   'investigative',
#   'powers',
#   'giving',
#   'bureau',
#   'greater',
#   'ability',
#   'visit',
#   'monitor',
#   'web',
#   'sites',
#   'mosques',
#   'public',
#   'entities',
#   'developing',
#   'terrorism',
#   'leads'],
#  ['bureau',
#   'authority',
#   'investigate',
#   'groups',
#   'suspected',
#   'ties',
#   'foreign',
#   'terrorists',
#   'protest',
#   'groups',
#   'suspected',
#   'having',
#   'links',
#   'violent',
#   'disruptive',
#   'activities'],
#  ['documents',
#   'coming',
#   'bush',
#   'administration',
#   'confirmation',
#   'president',
#   'bush',
#   'authorized',
#   'spying',
#   'warrants',
#   'fighting',
#   'terrorism',
#   'prompted',
#   'charges',
#   'civil',
#   'rights',
#   'advocates',
#   'government',
#   'improperly',
#   'blurred',
#   'line',
#   'terrorism',
#   'acts',
#   'civil',
#   'disobedience',
#   'lawful',
#   'protest'],
#  ['doubt',
#   'current',
#   'proprietors',
#   'executive',
#   'branch',
#   'spy',
#   'domestic',
#   'political',
#   'enemies',
#   'guise',
#   'protecting',
#   'terrorism'],
#  ['separate',
#   'points',
#   'evidence',
#   'required',
#   'exactly',
#   'politically',
#   'acceptable',
#   'public'],
#  ['paranoia',
#   'watching',
#   'point',
#   'environmental',
#   'activists',
#   'assume',
#   'demonstrated',
#   'watched'],
#  ['cameron',
#   'arnold',
#   'lead',
#   'brigade',
#   'celeb',
#   'eco',
#   'spokesfolk',
#   'formative',
#   'experiences',
#   'led',
#   'movie',
#   'star',
#   'galactic',
#   'hottie',
#   'cameron',
#   'diaz',
#   'commitment',
#   'environment'],
#  ['dude'],
#  ['life'],
#  ['life'],
#  ['said', 'better'],
#  ['hotter'],
#  ['diaz',
#   'bringing',
#   'commitment',
#   'new',
#   'mtv',
#   'series',
#   'called',
#   'trippin',
#   'debuting',
#   'tonight',
#   'travels',
#   'world',
#   'ecological',
#   'hotspots',
#   'toting',
#   'entourage',
#   'fish',
#   'water',
#   'celebrities'],
#  ['upcoming',
#   'episodes',
#   'rapper',
#   'dmx',
#   'camping',
#   'yellowstone',
#   'diaz',
#   'boy',
#   'toy',
#   'justin',
#   'timberlake',
#   'demonstrate',
#   'beat',
#   'boxing',
#   'skills',
#   'masai',
#   'tribe',
#   'members',
#   'kenya'],
#  ['god',
#   'brains',
#   'explode',
#   'sheer',
#   'meta',
#   'meta',
#   'meta',
#   'ironic',
#   'glory'],
#  ['diaz', 'celeb', 'trippin', 'environment'],
#  ['actors',
#   'ed',
#   'norton',
#   'matt',
#   'damon',
#   'provide',
#   'narration',
#   'upcoming',
#   'green',
#   'themed',
#   'pbs',
#   'series'],
#  ['yesterday',
#   'action',
#   'movie',
#   'star',
#   'wait',
#   'told',
#   'governor',
#   'california'],
#  ['arnold',
#   'schwarzenegger',
#   'appeared',
#   'extreme',
#   'makeover',
#   'home',
#   'edition',
#   'demonstrate',
#   'wonders',
#   'photovoltaic',
#   'solar_panels'],
#  ['truly', 'live', 'interesting', 'times'],
#  ['depletion',
#   'oil',
#   'gas',
#   'degradation',
#   'environment',
#   'decline',
#   'social',
#   'capital',
#   'threaten',
#   'collapse',
#   'market',
#   'economy'],
#  ['fleming',
#   'believes',
#   'collapse',
#   'averted',
#   'public',
#   'policy',
#   'concentrate',
#   'laying',
#   'foundations',
#   'transformed',
#   'political',
#   'economy',
#   'rise',
#   'ashes'],
#  ['lecture',
#   'explored',
#   'social',
#   'cultural',
#   'qualities',
#   'indispensable',
#   'surviving',
#   'crash',
#   'moving',
#   'recovery',
#   'renewal',
#   'stability'],
#  ['-feasta',
#   'ecology',
#   'party',
#   'green',
#   'party',
#   'office',
#   'flat',
#   'hampstead'],
#  ['member',
#   'team',
#   'wrote',
#   'pamphlet',
#   'called',
#   'reckoning',
#   'cover',
#   'picture',
#   'cartoonist',
#   'peyton',
#   'large',
#   'number',
#   'circus',
#   'clowns',
#   'optimistically',
#   'balancing',
#   'barrel',
#   'oil'],
#  ['felt',
#   'quarter',
#   'century',
#   'left',
#   'prepare',
#   'moment',
#   'mad',
#   'reckless',
#   'pyramid',
#   'collapsed',
#   'pamphlet',
#   'proposed',
#   'comprehensive',
#   'reform',
#   'energy',
#   'industry',
#   'society',
#   'land',
#   'culture',
#   'beginning',
#   'straight',
#   'away',
#   'prepare',
#   'world',
#   'oil'],
#  ['pity', 'took', 'notice'],
#  ['irreversible', 'energy', 'shortage', 'break', 'near', 'future'],
#  ['damaging', 'years', 'intensive', 'preparation'],
#  ['event', 'lucky', 'denial', 'ends', 'time', 'notice', 'period', 'months'],
#  ['short', 'days'],
#  ['hit',
#   'oil',
#   'famine',
#   'joined',
#   'problems',
#   'way',
#   'need',
#   'respond',
#   'avalanche'],
#  ['point',
#   'trying',
#   'stop',
#   'instead',
#   'survive',
#   'think',
#   'start',
#   'safer',
#   'ground',
#   'totally',
#   'different',
#   'principles'],
#  ['oil',
#   'gas',
#   'begin',
#   'conventional',
#   'crude_oil',
#   'stuff',
#   'pumped',
#   'oilwells',
#   'reasonably',
#   'accessible',
#   'places',
#   'land',
#   'sea',
#   'bed',
#   'source',
#   'petroleum',
#   'use',
#   'today',
#   '\xad'],
#  ['main', 'thing', 'remember', 'order', 'produce', 'discover'],
#  ['obvious', 'important', 'corollary'],
#  ['production',
#   'follows',
#   'discovery',
#   'order',
#   'years',
#   'draw',
#   'graph',
#   'rate',
#   'oil',
#   'discovered',
#   'particular',
#   'place',
#   'curve',
#   'left',
#   'figure',
#   'draw',
#   'graph',
#   'rate',
#   'produced',
#   'curve',
#   'right'],
#  ['figure', 'production', 'oil', 'follows', 'discovery'],
#  ['figure', 'pictures', 'drawn', 'real', 'numbers', 'world'],
#  ['discovery',
#   'conventional',
#   'oil',
#   'peaked',
#   'means',
#   'production',
#   'conventional',
#   'oil',
#   'peaks',
#   'years',
#   'later'],
#  ['figure',
#   'peak',
#   'global',
#   'discoveries',
#   'conventional',
#   'oil',
#   'occurred',
#   'mid',
#   '1960s',
#   'followed',
#   'long',
#   'decline'],
#  ['production', 'peak', 'follows', 'years', 'later'],
#  ['source', 'colin', 'campbell', 'aspo', 'newsletter'],
#  ['conventional',
#   'crude_oil',
#   'far',
#   'convenient',
#   'form',
#   'oil',
#   'accessible',
#   'easy',
#   'pump',
#   'transport',
#   'refine'],
#  ['alternatives'],
#  ['unconventional',
#   'sources',
#   'oil',
#   'include',
#   'tar_sands',
#   'present',
#   'abundance',
#   'canada',
#   'heavy',
#   'oil',
#   'variety',
#   'places',
#   'notably',
#   'orinoco',
#   'oil',
#   'deposits',
#   'venezuela'],
#  ['difficulty',
#   'deposits',
#   'energy',
#   'intensive',
#   'produce',
#   'case',
#   'tar_sands',
#   'example',
#   'opencast',
#   'mines',
#   'dug',
#   'product',
#   'heated',
#   'compressed',
#   'waste',
#   'material',
#   'disposed',
#   'unstable',
#   'mountains',
#   'spoil'],
#  ['sure',
#   'energy',
#   'actually',
#   'derived',
#   'process',
#   'energy',
#   'massive',
#   'rich',
#   'flow',
#   'energy',
#   'comes',
#   'conventional',
#   'oil'],
#  ['deep',
#   'water',
#   'oil',
#   'm',
#   'ways',
#   'investigated',
#   'extracting',
#   'little',
#   'bit',
#   'enhanced',
#   'oil',
#   'recovery',
#   'conventional',
#   'oil',
#   'wells'],
#  ['natural_gas',
#   'liquids',
#   'gas',
#   'fields',
#   'making',
#   'useful',
#   'contribution',
#   'supply',
#   'oil',
#   'early',
#   '1970s',
#   'continue'],
#  ['main', 'alternative', 'oil', 'gas'],
#  ['world', 'percent', 'original', 'endowment'],
#  ['remainder',
#   'russia',
#   'end',
#   'long',
#   'pipeline',
#   'western',
#   'europeans',
#   'depend',
#   'middle_east'],
#  ['far',
#   'certain',
#   'stability',
#   'sources',
#   'sustained',
#   'global',
#   'political',
#   'economy',
#   'devastated',
#   'depletion',
#   'oil'],
#  ['figure', 'past', 'future', 'oil', 'worldwide'],
#  ['production',
#   'measured',
#   'gigabarrels',
#   'oil',
#   'equivalent',
#   'gigabarrel',
#   '=',
#   'barrels'],
#  ['cubic', 'feet', 'gas', 'taken', 'equivalent', 'barrels', 'oil'],
#  ['source', 'colin', 'campbell', 'aspo', 'newsletter'],
#  ['summarised', 'figure'],
#  ['best',
#   'estimate',
#   'peak',
#   'production',
#   'oil',
#   'worldwide',
#   'middle',
#   'decade'],
#  ['story',
#   'elaborated',
#   'adding',
#   'peak',
#   'depletion',
#   'gas',
#   'picture',
#   'hydrocarbons',
#   'effect',
#   'oil',
#   'peak',
#   'demand',
#   'gas',
#   'highly',
#   'uncertain',
#   'better',
#   'stay',
#   'oil',
#   'moment'],
#  ['oil',
#   'drives',
#   'world',
#   'transport',
#   'transport',
#   'drives',
#   'world',
#   'economy',
#   'necessary',
#   'condition',
#   'practically',
#   'material',
#   'need',
#   'urban',
#   'life'],
#  ['global',
#   'economy',
#   'relies',
#   'growing',
#   'production',
#   'oil',
#   'oil_production',
#   'decline'],
#  ['thinking', 'true', 'experts', 'forecasting', 'long', 'ago', '1960s'],
#  ['petroleum',
#   'geologist',
#   'king',
#   'hubbert',
#   'established',
#   'science',
#   '1950s'],
#  ['forecasts',
#   'oil_production',
#   'peak',
#   'turn',
#   'century',
#   'followed',
#   'fast',
#   'uk',
#   'department',
#   'energy',
#   'president',
#   'carter',
#   'global',
#   'report',
#   'president',
#   'geologists',
#   'oil',
#   'province',
#   'world',
#   'pooled',
#   'hard',
#   'evidence',
#   'consistently',
#   'disbelieved'],
#  ['know', 'taken', 'forecasts', 'seriously', 'built', 'solar', 'economy'],
#  ['taken',
#   'lead',
#   'meant',
#   'global',
#   'economy',
#   'cost',
#   'energy',
#   'given',
#   'technical',
#   'sophistication',
#   'economies',
#   'scale',
#   'developed',
#   'world',
#   'economy',
#   'low'],
#  ['global_warming', 'control'],
#  ['larger', 'oil', 'reserves', 'ground'],
#  ['increasingly',
#   'dependent',
#   'oil',
#   'provinces',
#   'half',
#   'century',
#   'old',
#   'showing',
#   'age',
#   'countries',
#   'middle_east',
#   'iran',
#   'iraq',
#   'saudi_arabia',
#   'united',
#   'arab',
#   'emirates'],
#  ['path',
#   'ahead',
#   'gentle',
#   'decline',
#   'percent',
#   'year',
#   'land',
#   'deep',
#   'trouble',
#   'prospects',
#   'global',
#   'growth',
#   'abruptly',
#   'stopped',
#   'energy',
#   'underpins',
#   'way',
#   'life',
#   'including',
#   'food_production',
#   'declining',
#   'quickly',
#   'rate',
#   'real',
#   'prospect',
#   'developing',
#   'alternatives',
#   'needed',
#   'scale'],
#  ['transition', 'unlikely', 'smooth'],
#  ['rivalry',
#   'access',
#   'oil',
#   'combined',
#   'near',
#   'monopoly',
#   'powers',
#   'hands',
#   'producers',
#   'set',
#   'scene',
#   'start',
#   'disruptions',
#   'supply'],
#  ['north_america',
#   'reserves',
#   'gas',
#   'reached',
#   'level',
#   'depletion',
#   'production',
#   'steep',
#   'decline',
#   'middle',
#   'years',
#   'decade'],
#  ['gas',
#   'fuel',
#   'heats',
#   'american',
#   'homes',
#   'drives',
#   'industry',
#   'provides',
#   'electricity',
#   'feedstock',
#   'fertiliser',
#   'imported',
#   'russia'],
#  ['gas',
#   'suddenly',
#   'scarce',
#   'america',
#   'vulnerable',
#   'dependent',
#   'increasingly',
#   'unstable',
#   'import',
#   'supply',
#   'lines',
#   'hydrocarbons',
#   'political',
#   'economy',
#   'depends'],
#  ['breakdowns',
#   'supply',
#   'increases',
#   'price',
#   'occur',
#   'surprise',
#   'dismay',
#   'odd',
#   'thing',
#   'considering',
#   'essential',
#   'nature',
#   'problem',
#   'understood',
#   'decades'],
#  ['new',
#   'technologies',
#   '\xad',
#   'renewables',
#   'conservation',
#   'systems',
#   'ways',
#   'substituting',
#   'oil',
#   'gas',
#   'coal',
#   '\xad',
#   'ready',
#   'developed'],
#  ['ready'],
#  ['market', 'economy', 'shock'],
#  ['like',
#   'army',
#   'caught',
#   'napping',
#   'time',
#   'reach',
#   'trusted',
#   'new',
#   'high',
#   'tech',
#   'equipment'],
#  ['threats', 'market', 'economy'],
#  ['coming',
#   'oil',
#   'shock',
#   'reason',
#   'prospects',
#   'global',
#   'market',
#   'economy',
#   'civilisation',
#   'look',
#   'poor'],
#  ['complex',
#   'system',
#   'car',
#   'human',
#   'body',
#   'tends',
#   'end',
#   'life',
#   'fail',
#   'different',
#   'ways',
#   'time'],
#  ['sign', 'systems', 'failure', 'climate_change'],
#  ['thirdly',
#   'complex',
#   'poorly',
#   'understood',
#   'issue',
#   'mature',
#   'market',
#   'economy',
#   'ideal',
#   'conditions',
#   'sustain',
#   'perpetual',
#   'economic_growth',
#   'essential',
#   'condition',
#   'stability',
#   'richard',
#   'douthwaite',
#   'argue',
#   'simply'],
#  ['fourthly',
#   'increasingly',
#   'intense',
#   'phenomenon',
#   'disengagement',
#   '\xad',
#   'failure',
#   'participation',
#   'consent',
#   'shared',
#   'values',
#   'social',
#   'cohesion',
#   '\xad',
#   'short',
#   'failure',
#   'social',
#   'capital',
#   'ultimately',
#   'matures',
#   'insurgency',
#   'dissidents',
#   'outside',
#   'modern',
#   'society'],
#  ['system',
#   'failing',
#   'ways',
#   'soil',
#   'fertility',
#   'water',
#   'hormone',
#   'disruptors',
#   'collapse',
#   'fisheries',
#   '\xad'],
#  ['find',
#   'looking',
#   'climax',
#   'market',
#   'economy',
#   'followed',
#   'comprehensive',
#   'failure',
#   'high',
#   'unemployment',
#   'atrophy',
#   'government',
#   'revenues',
#   'leading',
#   'called',
#   'hyperunemployment',
#   'unemployment',
#   'high',
#   'government',
#   'fund',
#   'subsistence',
#   'payments',
#   'pensions'],
#  ['unemployment', 'scale', 'means', 'income'],
#  ['income', 'means', 'food'],
#  ['food',
#   'means',
#   'collapse',
#   'urban',
#   'populations',
#   'scale',
#   'experienced',
#   'civic',
#   'societies',
#   '\xad',
#   'romans',
#   'dozen',
#   'accomplished',
#   'civilisations',
#   '\xad',
#   'closing',
#   'phase',
#   'life',
#   'cycles'],
#  ['hope', 'wrong', 'come'],
#  ['obvious',
#   'opportunity',
#   'rapidly',
#   'passing',
#   'possible',
#   'avoid',
#   'high',
#   'levels',
#   'mortality',
#   'associated',
#   'collapse',
#   'civic',
#   'societies'],
#  ['figure'],
#  ['climax', 'market', 'economy', 'steep', 'decline'],
#  ['damage',
#   'immediate',
#   'task',
#   'build',
#   'essential',
#   'structures',
#   'lean',
#   'economy',
#   'crisis',
#   'hyperunemployment',
#   'government',
#   'longer',
#   'maintain',
#   'subsistence',
#   'payments',
#   'unemployed'],
#  ['romans',
#   'long',
#   'period',
#   'troubles',
#   'years',
#   'empire',
#   'finally',
#   'collapsed'],
#  ['period',
#   'troubles',
#   'likely',
#   'condensed',
#   'figure',
#   'problems',
#   'mentioned',
#   'converging',
#   'fast'],
#  ['suggested', 'period', 'years', 'indicative'],
#  ['climax',
#   'market',
#   'economy',
#   'downturn',
#   'comes',
#   'employment',
#   'solid',
#   'line',
#   'falls',
#   'decisively',
#   'point',
#   'hyperunemployment',
#   'years'],
#  ['turning', 'point'],
#  ['according',
#   'arbitrary',
#   'time',
#   'intervals',
#   'giving',
#   'makes',
#   'point',
#   'hyperunemployment',
#   'consequences',
#   'occur'],
#  ['time',
#   'lean',
#   'economy',
#   'dashed',
#   'line',
#   'built',
#   'scale',
#   'provide',
#   'working',
#   'alternative',
#   'new',
#   'economic',
#   'social',
#   'order'],
#  ['new',
#   'domestication',
#   'want',
#   'draw',
#   'attention',
#   'advantage',
#   'asset',
#   'civilisation',
#   'bring',
#   'solving',
#   'problem',
#   'industry'],
#  ['world',
#   'hyperunemployment',
#   'market',
#   'breakdown',
#   'industry',
#   'substantially',
#   'bankrupt',
#   'course'],
#  ['developed', 'stunning', 'assets', 'course', 'century'],
#  ['developed',
#   'technology',
#   'capable',
#   'instance',
#   'working',
#   'small',
#   'scale',
#   'learning',
#   'capture',
#   'energy',
#   'store',
#   'little',
#   'results'],
#  ['industry',
#   'successfully',
#   'developed',
#   'methods',
#   'creating',
#   'effective',
#   'human',
#   'groups',
#   'keeping',
#   'working',
#   'constructively'],
#  ['creative'],
#  ['understanding',
#   'way',
#   'systems',
#   'function',
#   'audit',
#   'proposal',
#   'unintended',
#   'consequences',
#   'avoid',
#   'denial'],
#  ['worked',
#   'manage',
#   'efficiency',
#   'lean',
#   'production',
#   'systems',
#   'recently',
#   'generally',
#   'decisive',
#   'effectiveness',
#   'lean',
#   'thinking'],
#  ['company',
#   'think',
#   'shining',
#   'example',
#   'properties',
#   'practice',
#   'companies',
#   'ultimate',
#   'values',
#   'culture',
#   'tend',
#   'thin',
#   'trivial'],
#  ['fundamentals',
#   'things',
#   'happen',
#   'neatly',
#   'minimum',
#   'waste',
#   'small',
#   'scale',
#   'companies',
#   'important',
#   'offer',
#   'fact',
#   'households',
#   'need',
#   'badly'],
#  ['failure',
#   'market',
#   'economy',
#   'households',
#   'lack',
#   'jobs',
#   'lack',
#   'state',
#   'handouts',
#   'lack',
#   'primary',
#   'goods',
#   'food',
#   'water',
#   'energy',
#   'materials'],
#  ['things',
#   'matter',
#   'provide',
#   'basis',
#   'coping',
#   'life',
#   'things',
#   'urban',
#   'populations',
#   'easily',
#   'provide'],
#  ['primaries',
#   'fall',
#   'range',
#   'assets',
#   'open',
#   'households',
#   'revolution',
#   'effectiveness',
#   'producers'],
#  ['households',
#   'need',
#   'competent',
#   'future',
#   'industry',
#   'need',
#   'use',
#   'industry',
#   'technologies',
#   'practices'],
#  ['revolution', 'new', 'domestication'],
#  ['inspiration'],
#  ['years',
#   'ago',
#   'evolution',
#   'human',
#   'society',
#   'human',
#   'groups',
#   'gradually',
#   'began',
#   'turn',
#   'away',
#   'hunter',
#   'gatherers'],
#  ['instead',
#   'going',
#   'foraging',
#   'taking',
#   'found',
#   'began',
#   'instead',
#   'bring',
#   'animals',
#   'plants',
#   'perimeter',
#   'fence',
#   'domesticating',
#   'taking',
#   'direct',
#   'responsibility',
#   'fulfilment',
#   'primary',
#   'needs'],
#  ['start', 'big'],
#  ['domestication'],
#  ['suggest',
#   'lies',
#   'ahead',
#   'domestication',
#   'instead',
#   'relying',
#   'industry',
#   'work',
#   'foraging',
#   'market',
#   'households',
#   'local',
#   'economies',
#   'bring',
#   'industrial',
#   'insights',
#   'technologies',
#   'speak',
#   'perimeter',
#   'fence',
#   'bringing',
#   'direct',
#   'control'],
#  ['new',
#   'domestication',
#   'seen',
#   'local',
#   'economies',
#   'process',
#   'growing',
#   'evolution',
#   'means',
#   'survival',
#   'midst',
#   'global',
#   'economic',
#   'catastrophe',
#   'vision',
#   'civility'],
#  ['heart', 'market', 'economy', 'idea', 'specialisation', 'labour'],
#  ['adam', 'smith', 'explained', 'story', 'sure', 'remember'],
#  ['want',
#   'lot',
#   'pins',
#   'men',
#   'turn',
#   'individual',
#   'completing',
#   'pins',
#   'divide',
#   'job',
#   'parts',
#   'man',
#   'parts',
#   'output',
#   'pins',
#   'smith',
#   'calculated',
#   'times'],
#  ['civilisations', 'crash'],
#  ['end',
#   'political',
#   'economy',
#   'flips',
#   'different',
#   'lightweight',
#   'decentralised',
#   'order',
#   'romans',
#   'discovery'],
#  ['civic', 'society', 'history'],
#  ['specialisation', 'triggers', 'astonishing', 'spiral', 'elaboration'],
#  ['sequence',
#   'goes',
#   'specialisation',
#   'productivity',
#   'concentration',
#   'specialists',
#   'towns'],
#  ['long',
#   'distances',
#   'transport',
#   'police',
#   'forces',
#   'money',
#   'bureaucrats'],
#  ['need', 'lots', 'equipment', 'productivity', 'specialisation'],
#  ['capture',
#   'concentration',
#   'particular',
#   'functions',
#   'particular',
#   'places'],
#  ['sequence', 'dynamic', 'virtually', 'impossible', 'stop'],
#  ['expensive', 'business'],
#  ['complicated'],
#  ['takes', 'lot', 'swapping', 'work'],
#  ['eventually', 'crashes', 'weight'],
#  ['civilisations', 'crash'],
#  ['end',
#   'political',
#   'economy',
#   'flips',
#   'different',
#   'lightweight',
#   'decentralised',
#   'order',
#   'requiring',
#   'drastically',
#   'reduced',
#   'quantity',
#   'goods',
#   'services',
#   'minimal',
#   'transport',
#   'specialisation'],
#  ['response', 'people', 'localities', 'start', 'provide', 'need'],
#  ['inevitable', 'sequel', 'closing', 'stages', 'civic', 'society'],
#  ['past',
#   'closing',
#   'stages',
#   'led',
#   'collapse',
#   'dark',
#   'ages',
#   'population',
#   'venerable',
#   'bede',
#   'cut',
#   'like',
#   'ripe',
#   'corn'],
#  ['argue',
#   'sooner',
#   'start',
#   'build',
#   'distributed',
#   'decentralised',
#   'broadly',
#   'competent',
#   'local',
#   'economies',
#   'realistic',
#   'pain',
#   'grief',
#   'greater',
#   'prospects',
#   'evolution',
#   'market',
#   'economy',
#   'making',
#   'inherited',
#   'building'],
#  ['figure'],
#  ['rethinking',
#   'land',
#   'use',
#   'market',
#   'economy',
#   'pattern',
#   'capture',
#   'concentration',
#   'large',
#   'centres',
#   'linked',
#   'routine',
#   'transport',
#   'inappropriate',
#   'stabilised',
#   'lean',
#   'economy',
#   'future',
#   'require',
#   'sophisticated',
#   'complex',
#   'organisation'],
#  ['logical', 'sequence', 'goes', 'like', 'figure'],
#  ['start',
#   'capture',
#   'concentration',
#   'left',
#   'hand',
#   'panel',
#   'big',
#   'concentrated',
#   'producers',
#   'far',
#   'home',
#   'sequence',
#   'moves',
#   'greater',
#   'local',
#   'complexity',
#   'centre',
#   'panel',
#   'smaller',
#   'producers'],
#  ['onwards', 'complex', 'economy', 'right', 'hand', 'panel'],
#  ['integration',
#   'functions',
#   'small',
#   'local',
#   'scale',
#   'creates',
#   'complex',
#   'economic',
#   'social',
#   'orders',
#   'communities',
#   'having',
#   'substantial',
#   'qualities',
#   'self',
#   'sufficiency',
#   'dependent',
#   'wider',
#   'ecosystem',
#   'integrate',
#   'properties',
#   'belonging',
#   'independence'],
#  ['diversity',
#   'robustness',
#   'shocks',
#   'ability',
#   'learn',
#   'experience',
#   'good',
#   'use',
#   'available',
#   'niches',
#   'opportunities',
#   'innovate'],
#  ['notice',
#   'routine',
#   'transport',
#   'churning',
#   'b',
#   'c',
#   'd.',
#   'journeys',
#   'h',
#   'place',
#   'adapted',
#   'circumstance',
#   'develops',
#   'personality'],
#  ['sense', 'place'],
#  ['presumption',
#   'place',
#   'learned',
#   'hang',
#   'material',
#   'assets',
#   'use',
#   'use',
#   'materials',
#   'today',
#   'waste',
#   'tomorrow',
#   'resources',
#   'perpetual',
#   'cycle',
#   'renewal',
#   'known',
#   'closed',
#   'system'],
#  ['closed', 'systems'],
#  ['solution', 'lies'],
#  ['closed', 'systems', 'form', 'local', 'organisation', 'local', 'economies'],
#  ['alternative'],
#  ['able', 'buy', 'needs', 'import', 'way', 'trouble'],
#  ['local', 'lean', 'economies', 'simply', 'good', 'idea', 'option'],
#  ['organised', 'principles', 'lean', 'thinking'],
#  ['closed',
#   'systems',
#   'lean',
#   'thinking',
#   'adapted',
#   'context',
#   'establishing',
#   'sustaining',
#   'closed',
#   'system',
#   'provides',
#   'food',
#   'water',
#   'energy',
#   'materials',
#   'local',
#   'resources',
#   'far',
#   'possible',
#   'conserves',
#   'renews',
#   'primary',
#   'assets',
#   'local',
#   'economy'],
#  ['closed',
#   'system',
#   'means',
#   'material',
#   'imports',
#   'material',
#   'waste',
#   'dependence',
#   'solar_energy'],
#  ['completely',
#   'closed',
#   'systems',
#   'human',
#   'affairs',
#   'scale',
#   'planet',
#   'local',
#   'scale',
#   'closer',
#   'present'],
#  ['closed',
#   'system',
#   'case',
#   'food',
#   'requires',
#   'fertility',
#   'retained',
#   'locally',
#   'nitrogen',
#   'phosphates',
#   'potash',
#   'micronutrients'],
#  ['conserved',
#   'capital',
#   'composted',
#   'fertility',
#   'including',
#   'human',
#   'waste',
#   'simply',
#   'sustained',
#   'built',
#   'extraordinarily',
#   'high',
#   'local',
#   'yields',
#   'achieved',
#   'virtuosos',
#   'food_production',
#   'alan',
#   'chadwick',
#   'john',
#   'jeavons'],
#  ['water',
#   'rains',
#   'course',
#   'droughts',
#   'global_warming',
#   'intensifies',
#   'rainy',
#   'climate',
#   'local',
#   'economy',
#   'needs',
#   'maintain',
#   'shall',
#   'conservation',
#   'system',
#   'use',
#   'water'],
#  ['reasons',
#   'lean',
#   'production',
#   'use',
#   'aquaculture',
#   'productive',
#   'food',
#   'system',
#   'soil',
#   'secondly',
#   'permaculture',
#   'loves',
#   'closed',
#   'circular',
#   'systems',
#   'typically',
#   'central',
#   'place',
#   'water',
#   'instance',
#   'pond',
#   'habitat',
#   'water',
#   'weeds',
#   'fertilise',
#   'land',
#   'grows',
#   'food',
#   'attacked',
#   'slugs',
#   'eaten',
#   'ducks',
#   'live',
#   'pond',
#   'fertilise',
#   'water',
#   'weeds'],
#  ['water', 'way', 'connecting', 'things'],
#  ['immensely',
#   'effective',
#   'form',
#   'japanese',
#   'aigamo',
#   'method',
#   'rice',
#   'production'],
#  ['times',
#   'productive',
#   'given',
#   'area',
#   'land',
#   'high',
#   'tech',
#   'agriculture'],
#  ['case',
#   'energy',
#   'closed',
#   'systems',
#   'apply',
#   'defined',
#   'terms',
#   'materials',
#   'energy',
#   'takes',
#   'way',
#   'ticket',
#   'sun',
#   'dissipation',
#   'form',
#   'low',
#   'level',
#   'heat'],
#  ['principle',
#   'similar',
#   'lean',
#   'economy',
#   'built',
#   'solar',
#   'string',
#   'technologies',
#   'forms',
#   'renewable_energy',
#   'derived',
#   'ultimately',
#   'sun',
#   'strung',
#   'minigrid',
#   'member',
#   'grid',
#   'generator',
#   'user',
#   'storage',
#   'depot',
#   'opportunity',
#   'offers'],
#  ['minigrid',
#   'uses',
#   'range',
#   'technologies',
#   'including',
#   'solar',
#   'wind',
#   'water',
#   'biomass',
#   'conserving',
#   'energy',
#   'use',
#   'benign',
#   'army',
#   'emerging',
#   'energy',
#   'technologies',
#   'way'],
#  ['stores',
#   'energy',
#   'use',
#   'media',
#   'hydrogen',
#   'biomass',
#   'supercapacitors',
#   'flywheels',
#   'ceramics',
#   'pumped',
#   'storage'],
#  ['uses', 'information', 'technology', 'manage', 'demand'],
#  ['giant',
#   'users',
#   'energy',
#   'transport',
#   'industry',
#   'houses',
#   'leak',
#   'energy',
#   'world'],
#  ['stabilised',
#   'lean',
#   'economy',
#   'gives',
#   'sharp',
#   'ambitious',
#   'meaning',
#   'energy_efficiency'],
#  ['changes',
#   'behaviour',
#   'including',
#   'example',
#   'drastically',
#   'reduced',
#   'dependency',
#   'transport',
#   'reduce',
#   'demand',
#   'energy',
#   'services',
#   'thirds',
#   'factor',
#   'energy_efficiency',
#   'energy',
#   'services',
#   'provided',
#   'kilowatt',
#   'energy',
#   'improved'],
#  ['multiplies',
#   'percent',
#   'improvement',
#   'demand',
#   'percent',
#   'energy',
#   'use',
#   'capability',
#   'renewables'],
#  ['transition', 'require', 'energy', 'rationing'],
#  ['electronic',
#   'rationing',
#   'system',
#   'energy',
#   'called',
#   'domestic',
#   'tradable',
#   'quotas',
#   'dtqs',
#   'uses',
#   'information',
#   'technology',
#   'distribute',
#   'fair',
#   'access',
#   'fossil_fuels',
#   'guaranteeing',
#   'year',
#   'year',
#   'budget',
#   'reduced',
#   'consumption',
#   'achieved'],
#  ['dtq', 'budget', 'looks', 'like', 'figure'],
#  ['basis',
#   'step',
#   'step',
#   'decline',
#   'emissions',
#   'carbon_dioxide',
#   'fossil_fuels'],
#  ['argue',
#   'way',
#   'achieving',
#   'equitable',
#   'allocation',
#   'declining',
#   'access',
#   'fuel',
#   'face',
#   'near',
#   'future'],
#  ['need',
#   'national',
#   'scheme',
#   'firmly',
#   'based',
#   'strong',
#   'sense',
#   'national',
#   'solidarity'],
#  ['significance', 'extends', 'energy'],
#  ['decisive',
#   'persistent',
#   'reduction',
#   'energy',
#   'use',
#   'provide',
#   'pathway',
#   'present',
#   'day',
#   'economy',
#   'achieve',
#   'transition',
#   'massive',
#   'achievement',
#   'happened',
#   'stabilised',
#   'lean',
#   'economy'],
#  ['figure'],
#  ['carbon',
#   'budget',
#   'domestic',
#   'tradable',
#   'quotas',
#   'defined',
#   'years',
#   'years',
#   'commitment',
#   'changed',
#   'years',
#   'set',
#   'advance',
#   'revised'],
#  ['year',
#   'forecast',
#   'gives',
#   'guidance',
#   'scale',
#   'reduction',
#   'expected',
#   'future'],
#  ['budget',
#   'represents',
#   'guarantee',
#   'reduction',
#   'targets',
#   'met',
#   'enables',
#   'people',
#   'informed',
#   'preparation'],
#  ['greening', 'waste'],
#  ['material', 'economy'],
#  ['going', 'skip', 'matter', 'dirty', 'detail'],
#  ['thing',
#   'come',
#   'end',
#   'review',
#   'practical',
#   'matters',
#   'food',
#   'water',
#   'energy',
#   'materials'],
#  ['consumer', 'driven', 'economy', 'sense', 'guilt', 'material', 'goods'],
#  ['understandable',
#   'strange',
#   'sense',
#   'previous',
#   'societies',
#   'existed',
#   'sustainable',
#   'coexistence',
#   'environment',
#   'comfortable',
#   'goods',
#   'waste'],
#  ['certainly', 'vastly', 'smaller', 'scale', 'society', 'sense', 'comparison'],
#  ['sense', 'comparison'],
#  ['complex', 'argument', 'trail', 'past'],
#  ['argument',
#   'goes',
#   'primitive',
#   'societies',
#   'fact',
#   'incredibly',
#   'productive'],
#  ['environments', 'fertile', 'produce', 'abundance', 'easily'],
#  ['fact', 'produced', 'problem', 'rid', 'excess'],
#  ['ecosystems',
#   'develop',
#   'ways',
#   'getting',
#   'rid',
#   'excess',
#   'evolving',
#   'vast',
#   'array',
#   'charismatic',
#   'predators'],
#  ['early',
#   'human',
#   'societies',
#   'faced',
#   'excess',
#   'regarded',
#   'excess',
#   'curse',
#   'la',
#   'maudite',
#   'claude',
#   'bataille',
#   'words'],
#  ['accursed', 'share'],
#  ['set', 'wasting', 'potlatches', 'sacrifices', 'parties'],
#  ['tibetan',
#   'monks',
#   'day',
#   'immensely',
#   'complex',
#   'sand',
#   'mandalas',
#   'months',
#   'painstaking',
#   'work',
#   'huge',
#   'quantity',
#   'embodied',
#   'human',
#   'capital',
#   'magnificent',
#   'investment',
#   'chuck',
#   'river',
#   'delectation',
#   'river',
#   'god'],
#  ['problem', 'solved'],
#  ['contrast',
#   'market',
#   'economy',
#   'create',
#   'vast',
#   'investment',
#   'use',
#   'create',
#   'vast',
#   'investment'],
#  ['accumulate'],
#  ['bataille',
#   'suggested',
#   'bigger',
#   'accumulated',
#   'capital',
#   'bigger',
#   'eventual',
#   'crash'],
#  ['primitive', 'societies', 'knew', 'better', 'kept', 'stakes', 'low'],
#  ['fun'],
#  ['tell'],
#  ['greening', 'waste'],
#  ['lean', 'economy', 'lean', 'society', 'come'],
#  ['lean',
#   'consumption',
#   'considers',
#   'vast',
#   'quantity',
#   'goods',
#   'services',
#   'consumed',
#   'households',
#   'government',
#   'fact'],
#  ['thing',
#   'recognise',
#   'lean',
#   'economy',
#   'burning',
#   'question',
#   'reducing',
#   'consumption'],
#  ['contrary', 'aim', 'increase', 'consumption'],
#  ['deep',
#   'economic',
#   'meltdown',
#   'occur',
#   'failure',
#   'market',
#   'economy',
#   'fine',
#   'job',
#   'reducing',
#   'consumption',
#   'catastrophic',
#   'levels'],
#  ['try', 'increase', 'consumption', 'able', 'increase', 'far'],
#  ['sort', 'economic', 'social', 'order', 'possible', 'travels', 'light'],
#  ['forced', 'travel', 'light'],
#  ['great',
#   'support',
#   'systems',
#   'transport',
#   'waste',
#   'disposal',
#   'systems',
#   'infrastructure',
#   'bureaucracy',
#   'security',
#   'large',
#   'scale',
#   'state',
#   'services',
#   'longer'],
#  ['regrettable',
#   'necessities',
#   'large',
#   'scale',
#   'society',
#   'brought',
#   'size',
#   'localised',
#   'internalised',
#   'reintegrated',
#   'community',
#   'fact',
#   'substantially',
#   'eliminated'],
#  ['inverse',
#   'usual',
#   'green',
#   'interpretation',
#   'matter',
#   'needs',
#   'dramatically',
#   'reduced',
#   'circumstances',
#   'outside',
#   'control',
#   'lucky',
#   'able',
#   'indulge',
#   'wants'],
#  ['require',
#   'radically',
#   'different',
#   'way',
#   'land',
#   'new',
#   'conception',
#   'industry',
#   'integrated',
#   'localities',
#   'domesticated'],
#  ['culture', 'needed'],
#  ['lean', 'culture'],
#  ['need',
#   'think',
#   'moment',
#   'reasonable',
#   'question',
#   'ask',
#   'society',
#   'actually',
#   'needs',
#   'culture'],
#  ['jobs',
#   'income',
#   'body',
#   'law',
#   'police',
#   'force',
#   'enforce',
#   'need',
#   'sense',
#   'solidarity',
#   'conferred',
#   'culture'],
#  ['substantial', 'degree'],
#  ['explained',
#   'somewhat',
#   'ambiguously',
#   'adam',
#   'smith',
#   'long',
#   'functioning',
#   'market',
#   'need',
#   'feel',
#   'particular',
#   'sense',
#   'benevolence'],
#  ['needed',
#   'butcher',
#   'baker',
#   'useful',
#   'services',
#   'offer',
#   'hungry',
#   'income'],
#  ['karl',
#   'polanyi',
#   'celebrated',
#   'book',
#   'great',
#   'transformation',
#   'published',
#   'thought',
#   'presence',
#   'market',
#   'economy',
#   'amazing',
#   'mechanism',
#   'automatically',
#   'regulating',
#   'society',
#   'keeping',
#   'order',
#   'great',
#   'loyalties',
#   'obligations',
#   'traditions',
#   'previous',
#   'age',
#   'needed'],
#  ['fatal',
#   'flaw',
#   'idea',
#   'self',
#   'regulating',
#   'market',
#   'polanyi',
#   'points',
#   'fatal',
#   'flaw',
#   'idea',
#   'self',
#   'regulating',
#   'market',
#   'economy',
#   'lack',
#   'safety',
#   'net'],
#  ['market',
#   'economy',
#   'reason',
#   'break',
#   'left',
#   'loyalties',
#   'obligations',
#   'traditions',
#   'society',
#   'previous',
#   'age',
#   'held'],
#  ['problem'],
#  ['mean', 'society', 'simply', 'disintegrate', 'level', 'crowd', 'riot'],
#  ['loyalties',
#   'obligations',
#   'traditions',
#   'form',
#   'culture',
#   'broken',
#   'hard'],
#  ['polanyi',
#   'right',
#   'knew',
#   'wrote',
#   'diligently',
#   'dismantling',
#   'trace',
#   'loyalties',
#   'obligations',
#   'traditions',
#   'taking',
#   'traces',
#   'left',
#   'mixed',
#   'remains',
#   'cultures',
#   'divisive',
#   'refer',
#   'terms',
#   'loyalty',
#   'particular',
#   'culture',
#   'remnants',
#   'social',
#   'cohesion',
#   'left',
#   'instruments',
#   'disorder'],
#  ['double', 'bind'],
#  ['mess'],
#  ['contend'],
#  ['know',
#   'impossible',
#   'look',
#   'aspect',
#   'economy',
#   'society',
#   'context',
#   'lies',
#   'ahead',
#   'prospects',
#   'energy',
#   'food',
#   'climate_change',
#   'land',
#   'use',
#   'skills',
#   'social',
#   'order',
#   'international',
#   'order',
#   'culture',
#   'reflecting',
#   'governed',
#   'malevolent',
#   'devils',
#   'mess'],
#  ['start'],
#  ['rebuild',
#   'culture',
#   'multiple',
#   'culture',
#   'making',
#   'celebratory',
#   'virtue',
#   'diversity'],
#  ['need', 'idea', 'job', 'strong', 'culture'],
#  ['great',
#   'deal',
#   'local',
#   'economies',
#   'renewable_energy',
#   'local',
#   'currencies',
#   'material',
#   'need',
#   'sufficient',
#   'incentive',
#   'wholehearted',
#   'cooperation'],
#  ['talking',
#   'looking',
#   'society',
#   'capable',
#   'lasting',
#   'long',
#   'time',
#   'picking',
#   'defunct',
#   'market',
#   'economy',
#   'containing',
#   'channelling',
#   'ambitions',
#   'providing',
#   'social',
#   'cognitive',
#   'setting',
#   'greatest',
#   'minds',
#   'fun',
#   'tolerating',
#   'dissidence',
#   'moving',
#   'sustainable',
#   'development',
#   'environmental',
#   'policy',
#   'joining',
#   'build',
#   'political',
#   'economy',
#   'new',
#   'era'],
#  ['local',
#   'economies',
#   'achieve',
#   'future',
#   'survival',
#   'permanence',
#   'civility'],
#  ['vital', 'functions', 'culture', 'lean', 'economy', 'easy'],
#  ['culture'],
#  ['shall',
#   'leave',
#   'environment',
#   'far',
#   'talk',
#   'human',
#   'culture',
#   'permanence',
#   'bounce'],
#  ['society',
#   'culture',
#   'things',
#   'happen',
#   'horrible',
#   'falls',
#   'apart',
#   'develops',
#   'simplistic',
#   'cultures',
#   'hoof',
#   'fundamentalisms',
#   'beginning',
#   'find'],
#  ['lean', 'culture', 'important', 'parts', 'lean', 'economy'],
#  ['need'],
#  ['lean', 'culture', 'things'],
#  ['cohesion', 'foundation', 'social', 'cohesion'],
#  ['allows',
#   'society',
#   'recognise',
#   'having',
#   'common',
#   'simply',
#   'sense',
#   'people',
#   'time',
#   'time',
#   'instrumentally',
#   'useful'],
#  ['social',
#   'cohesion',
#   'implies',
#   'willingness',
#   'recognise',
#   'society',
#   'exists',
#   'contains',
#   'institutions',
#   'valued',
#   'cooperative',
#   'behaviour',
#   'justified',
#   'encouraged'],
#  ['key',
#   'understanding',
#   'idea',
#   'consent',
#   'willing',
#   'acceptance',
#   'person',
#   'association',
#   'society',
#   'sense',
#   'obligation',
#   'matter',
#   'making',
#   'choice',
#   'recognising',
#   'covenant'],
#  ['great',
#   'irish',
#   'political',
#   'philosopher',
#   'edmund',
#   'burke',
#   'brought',
#   'ballyduff',
#   'county',
#   'cork',
#   'explains',
#   'men',
#   'choice',
#   'derive',
#   'benefits',
#   'association',
#   'choice',
#   'subjected',
#   'duties',
#   'consequence',
#   'benefits',
#   'choice',
#   'enter',
#   'virtual',
#   'obligationas',
#   'binding',
#   'actual'],
#  ['powerful',
#   'bonding',
#   'implied',
#   'arrangement',
#   'destiny',
#   'burke',
#   'adds',
#   'strongest',
#   'moral',
#   'obligations',
#   'results',
#   'option'],
#  ['lean',
#   'culture',
#   'turns',
#   'social',
#   'cohesion',
#   'deeply',
#   'held',
#   'obligation'],
#  ['public',
#   'sphere',
#   'secondly',
#   'lean',
#   'culture',
#   'develop',
#   'public',
#   'sphere'],
#  ['public', 'sphere'],
#  ['distinction',
#   'private',
#   'public',
#   'immediately',
#   'obvious',
#   'easy',
#   'explain'],
#  ['think',
#   'best',
#   'way',
#   'explain',
#   'placing',
#   'immediately',
#   'context',
#   'local',
#   'economy'],
#  ['building', 'local', 'economy', 'odds', 'troubled', 'world'],
#  ['food', 'water', 'systems', 'currency', 'schools'],
#  ['community', 'claustrophobia'],
#  ['know'],
#  ['secrets'],
#  ['courtesies'],
#  ['danger',
#   'sheer',
#   'hell',
#   'truth',
#   'record',
#   'communities',
#   'staying',
#   'poor'],
#  ['defined',
#   'purpose',
#   'having',
#   'common',
#   'firms',
#   'communities',
#   'like',
#   'machynlleth',
#   'stayed',
#   'long',
#   'time'],
#  ['loose',
#   'local',
#   'economies',
#   'depend',
#   'basically',
#   'formal',
#   'economy',
#   'find',
#   'ways',
#   'cooperating',
#   'feel',
#   'like',
#   'got',
#   'reasonable',
#   'record',
#   'longevity'],
#  ['close',
#   'knit',
#   'communities',
#   'particularly',
#   'high',
#   'ambitions',
#   'sharing',
#   'cooperation',
#   'tend',
#   'survive'],
#  ['definitions', 'literature', 'survived'],
#  ['record',
#   'communities',
#   'staying',
#   'poor',
#   'reasons',
#   'particular',
#   'reason',
#   'talking',
#   'communities',
#   'cloying',
#   'sense',
#   'invasion',
#   'privacy'],
#  ['know',
#   'point',
#   'desperate',
#   'change',
#   'scenery',
#   'sense',
#   'invasion',
#   'privacy',
#   'sense',
#   'away',
#   'sense',
#   'want',
#   'talk',
#   'change',
#   'half',
#   'mind',
#   'neighbours',
#   'wanted',
#   'express'],
#  ['solution', 'develop', 'public', 'culture'],
#  ['makes', 'sound', 'simple'],
#  ['properties',
#   'public',
#   'culture',
#   'self',
#   'distance',
#   'form',
#   'play',
#   'skill',
#   'prefer',
#   'word',
#   'accomplishment'],
#  ['self', 'distance'],
#  ['impersonal', 'quality', 'sense', 'lack', 'spontaneity'],
#  ['discourse', 'tends', 'life', 'problems'],
#  ['reserve'],
#  ['clothes', 'point', 'better'],
#  ['comfortable',
#   'grunge',
#   'signals',
#   'hey',
#   'guy',
#   'unpretentious',
#   'presents'],
#  ['guy', 'kitted', 'oh', 'tie', 'instance', 'invites', 'question', 'game'],
#  ['game', 'sense', 'real', 'meaning', 'question', 'got', 'hide'],
#  ['admit', 've', 'got', 'lot', 'hide'],
#  ['told',
#   'irritating',
#   'sense',
#   'humour',
#   'anxiety',
#   'neurosis',
#   'workaholism',
#   'obsession',
#   'detail',
#   'erotic',
#   'feelings',
#   'seagulls',
#   'sha',
#   'tell',
#   'bore',
#   'sick',
#   'evening',
#   'quickly',
#   'pall',
#   'prospect',
#   'lifetime',
#   'fleming',
#   'self',
#   'revelation',
#   'simply',
#   'horrible'],
#  ['better', 'bit', 'impersonal'],
#  ['better',
#   'sustain',
#   'bit',
#   'reserve',
#   'great',
#   'writer',
#   'public',
#   'sphere',
#   'richard',
#   'sennett',
#   'describes',
#   'self',
#   'distance'],
#  ['starting', 'point', 'culture'],
#  ['exercise', 'self', 'revelation', 'public', 'expression'],
#  ['better', 'lecture', 'sustain', 'certain', 'detachment'],
#  ['reason', 'interested', 'think'],
#  ['bit',
#   'impersonal',
#   'try',
#   'instead',
#   'follow',
#   'logic',
#   'argument',
#   'lead',
#   'crucially',
#   'mind',
#   'hands',
#   'dirty',
#   'argument',
#   'leads',
#   'strange',
#   'uncomfortable',
#   'places',
#   'story',
#   'worth',
#   'reflecting'],
#  ['sense',
#   'reserve',
#   'self',
#   'distance',
#   'begin',
#   'capture',
#   'meaning',
#   'public',
#   'sphere'],
#  ['property', 'public', 'culture', 'turns', 'idea', 'play'],
#  ['play',
#   'core',
#   'themes',
#   'lean',
#   'economy',
#   'defining',
#   'conditions',
#   'rules',
#   'arbitrary'],
#  ['defeated', 'insulted', 'matter'],
#  ['victory', 'game', 'real', 'life', 'tyrant'],
#  ['offence', 'taken'],
#  ['play', 'lowers', 'temperature'],
#  ['relishes',
#   'play',
#   'context',
#   'extremes',
#   'self',
#   'expression',
#   'spilling',
#   'extremes',
#   'self',
#   'revelation'],
#  ['turn', 'opens', 'way', 'inclusiveness'],
#  ['play',
#   'context',
#   'interact',
#   'people',
#   'different',
#   'way',
#   'easily',
#   'context'],
#  ['play', 'core', 'themes', 'lean', 'economy'],
#  ['fun', 'means', 'low', 'serotonin', 'levels'],
#  ['young',
#   'children',
#   'join',
#   'older',
#   'children',
#   'game',
#   'left',
#   'older',
#   'children',
#   'conversation'],
#  ['inclusive', 'process', 'fun'],
#  ['fun', 'means', 'low', 'serotonin', 'levels'],
#  ['serotonin',
#   'neurotransmitter',
#   'levels',
#   'brain',
#   'run',
#   'low',
#   'result',
#   'liable',
#   'form',
#   'anger',
#   'attacks',
#   'addiction',
#   'violence',
#   'behaviour',
#   'antisocial',
#   'withdrawn',
#   'characteristics',
#   'community',
#   'breaking'],
#  ['serotonin',
#   'levels',
#   'brain',
#   'raised',
#   'excitement',
#   'confidence',
#   'success',
#   'particularly',
#   'success',
#   'thought',
#   'lost'],
#  ['things', 'provided', 'play'],
#  ['approach', 'public', 'sphere', 'takes', 'thinking', 'accomplishment'],
#  ['great',
#   'irish',
#   'philosopher',
#   'alasdair',
#   'macintyre',
#   'tells',
#   'calls',
#   'practice',
#   'thing'],
#  ['means',
#   'good',
#   'objective',
#   'skill',
#   'satisfied',
#   'mere',
#   'good',
#   'intentions',
#   'right'],
#  ['points',
#   'ways',
#   'accomplishment',
#   'affirms',
#   'needs',
#   'inheritance',
#   'community',
#   'past',
#   'accomplishments',
#   'traditions'],
#  ['personal',
#   'expressiveness',
#   'expressed',
#   'community',
#   'terms',
#   'belongs',
#   'medium',
#   'community',
#   'public',
#   'life'],
#  ['reasons',
#   'labelled',
#   'properties',
#   'self',
#   'distance',
#   'play',
#   'accomplishment',
#   'public',
#   'sphere',
#   'central'],
#  ['place', 'community', 'culture', 'happens'],
#  ['forget', 'solar_panels', 'local', 'food'],
#  ['local',
#   'economy',
#   'community',
#   'produce',
#   'accomplished',
#   'music',
#   'dance',
#   'celebration',
#   'chance'],
#  ['public',
#   'sphere',
#   'argument',
#   'support',
#   'claim',
#   'lean',
#   'culture',
#   'exceedingly',
#   'important'],
#  ['judgment'],
#  ['judgment', 'argument', 'goes', 'like'],
#  ['tendency',
#   'particularly',
#   'case',
#   'people',
#   'substantial',
#   'authority',
#   'judgment',
#   'poor'],
#  ['reasons',
#   'mainly',
#   'reduce',
#   'thinking',
#   'simplified',
#   'categories',
#   'universal',
#   'principles',
#   'apply',
#   'circumstances'],
#  ['stand', 'position'],
#  ['defined'],
#  ['represent',
#   'certain',
#   'view',
#   'certain',
#   'set',
#   'good',
#   'intentions',
#   'rigid',
#   'plausible',
#   'catastrophic',
#   'mind',
#   'set'],
#  ['like'],
#  ['alternative',
#   'dirty',
#   'detail',
#   'find',
#   'particular',
#   'circumstances',
#   'let',
#   'logic',
#   'speak'],
#  ['ambiguities',
#   'massive',
#   'exceptions',
#   'mediaeval',
#   'way',
#   'thinking',
#   'known',
#   'casuistry',
#   'point',
#   'avoiding',
#   'generalisations',
#   'idiot',
#   'simplifications',
#   'bernard',
#   'crick',
#   'calls'],
#  ['instead',
#   'casuistry',
#   'prefers',
#   'grips',
#   'specific',
#   'local',
#   'case',
#   'case',
#   'detail',
#   'powerful',
#   'advocates',
#   'notably'],
#  ['edmund',
#   'burke',
#   'aristotle',
#   'wrote',
#   'decisions',
#   'practical',
#   'theory',
#   'best',
#   'allow',
#   'resolve',
#   'particular',
#   'problem',
#   'context',
#   'eye',
#   'detailed',
#   'circumstances',
#   'particular',
#   'problem'],
#  ['comes', 'crunch', 'argument'],
#  ['particular', 'mean'],
#  ['means', 'things', 'particular', 'place'],
#  ['lean',
#   'economy',
#   'building',
#   'local',
#   'economies',
#   'making',
#   'particular',
#   'places',
#   'particular',
#   'associations',
#   'bringing',
#   'particular',
#   'places',
#   'life'],
#  ['lean', 'economy', 'located'],
#  ['culture', 'culture', 'place'],
#  ['art', 'celebrates', 'particular', 'place', 'quality', 'ritual'],
#  ['validates',
#   'place',
#   'gives',
#   'values',
#   'gives',
#   'people',
#   'courage',
#   'convictions',
#   'courage',
#   'locations'],
#  ['lean', 'society'],
#  ['brings', 'lean', 'society'],
#  ['market',
#   'economy',
#   'nice',
#   'regulating',
#   'price',
#   'mechanism',
#   'broken',
#   'necessary',
#   'rediscover',
#   'social',
#   'order',
#   'social',
#   'structure',
#   'principles',
#   'build',
#   'utopia',
#   'recognise',
#   'absolutely',
#   'undisputable',
#   'fact',
#   'social',
#   'order',
#   'future'],
#  ['market', 'wo', 'job'],
#  ['principle', 'society', 'imposed', 'led', 'guided', 'constructed'],
#  ['layers', 'lean', 'society'],
#  ['primary',
#   'group',
#   'essentially',
#   'extended',
#   'household',
#   'scale',
#   'adults'],
#  ['consist', 'families', 'door', 'round', 'turning', 'east', 'end', 'london'],
#  ['essential', 'building', 'block', 'social', 'order'],
#  ['secondly',
#   'households',
#   'located',
#   'describe',
#   'precinct',
#   'size',
#   'active',
#   'adults',
#   'scale',
#   'persistent',
#   'features',
#   'social',
#   'order',
#   'anthropological',
#   'record'],
#  ['possible',
#   'precinct',
#   'sustain',
#   'cooperation',
#   'exchange',
#   'systems',
#   'local',
#   'currency'],
#  ['possible', 'necessary', 'structure', 'social', 'order'],
#  ['skill', 'embedded', 'human', 'personality', 'developed'],
#  ['layer', 'parish', 'nation'],
#  ['want',
#   'finish',
#   'lecture',
#   'taking',
#   'closer',
#   'look',
#   'issues',
#   'arising',
#   'respect',
#   'scales',
#   'social',
#   'organisation'],
#  ['parish', 'strange', 'sort', 'size', 'terms', 'sociology'],
#  ['small',
#   'groups',
#   'primary',
#   'groups',
#   'large',
#   'group',
#   'form',
#   'nation',
#   'characteristic',
#   'form',
#   'reciprocity',
#   'particular',
#   'way',
#   'people',
#   'exchange',
#   'things',
#   'cooperate'],
#  ['households', 'generalised', 'reciprocity', 'unconditional', 'obligation'],
#  ['cooperate', 'people', 'household', 'unconditionally'],
#  ['extreme',
#   'people',
#   'local',
#   'unlikely',
#   'negative',
#   'reciprocity',
#   'exchange',
#   'based',
#   'principle',
#   'going'],
#  ['parishes', 'reciprocity', 'balanced', 'sort', 'half', 'way', 'house'],
#  ['local', 'currencies', 'absolutely', 'fundamental'],
#  ['right', 'scale', 'local', 'currency', 'parish'],
#  ['parish',
#   'easier',
#   'competitive',
#   'regime',
#   'tough',
#   'exchange',
#   'systems',
#   'exist',
#   'outside',
#   'parish',
#   'economies',
#   'order',
#   'local',
#   'currencies',
#   'carry'],
#  ['remember',
#   'state',
#   'economic',
#   'disorder',
#   'hyperunemployment',
#   'incomes',
#   'crashed',
#   'markets'],
#  ['likely', 'case', 'crashed', 'local', 'communities'],
#  ['local',
#   'currencies',
#   'absolutely',
#   'fundamental',
#   'task',
#   'getting',
#   'local',
#   'parish',
#   'economy',
#   'ground',
#   'protecting',
#   'tough'],
#  ['technique',
#   'like',
#   'suggest',
#   'based',
#   'absolutely',
#   'standard',
#   'fully',
#   'accepted',
#   'uncontroversial',
#   'principles',
#   'economics',
#   'criteria',
#   'exist',
#   'economy',
#   'enjoys',
#   'benefits',
#   'perfect',
#   'competition'],
#  ['modification', 'suggest', 'case', 'stood', 'completely', 'head'],
#  ['words',
#   'want',
#   'know',
#   'way',
#   'forward',
#   'future',
#   'listen',
#   'standard',
#   'neoclassical',
#   'economics',
#   'opposite'],
#  ['criteria', 'perfect', 'competition'],
#  ['large', 'number', 'sellers', 'buyers-', 'influence', 'prices'],
#  ['products', 'compete', 'price', 'criteria'],
#  ['free', 'entry', 'exit-', 'sellers', 'buyers', 'come', 'wish'],
#  ['profit', 'maximisation-', 'sellers', 'simply', 'money'],
#  ['local',
#   'standards',
#   'imposed',
#   'discrimination',
#   'grounds',
#   'price',
#   'producer'],
#  ['perfect',
#   'mobility',
#   'factors',
#   'production',
#   'labour',
#   'capital',
#   'land',
#   'follow',
#   'money',
#   'strings',
#   'attached'],
#  ['perfect', 'knowledge-'],
#  ['buyers', 'compare', 'quality', 'products', 'market'],
#  ['parishes', 'lean', 'economy', 'opposite', 'need', 'case'],
#  ['small',
#   'number',
#   'buyers',
#   'seller',
#   'lot',
#   'influence',
#   'local',
#   'market'],
#  ['immense',
#   'product',
#   'diversity',
#   'product',
#   'bundled',
#   'things',
#   'neighbourly',
#   'services',
#   'process',
#   'building',
#   'local',
#   'community'],
#  ['barriers', 'entry', 'exit'],
#  ['loyalty', 'local', 'suppliers', 'essential'],
#  ['bargain', 'hunting', 'best', 'price', 'essentially', 'cause', 'collapse'],
#  ['clear', 'objectives'],
#  ['forget'],
#  ['nature', 'lean', 'economy', 'improvising', 'invention', 'muddling'],
#  ['local',
#   'standards',
#   'standards',
#   'lean',
#   'production',
#   'confused',
#   'destructive',
#   'regulatory',
#   'regime',
#   'world',
#   'trade',
#   'organisation',
#   'eu',
#   'essential'],
#  ['barriers', 'mobility', 'factors', 'production'],
#  ['precisely',
#   'tissue',
#   'loyalties',
#   'obligations',
#   'traditions',
#   'keeps',
#   'labour',
#   'capital',
#   'home'],
#  ['imperfect', 'knowledge', 'absolutely', 'vital'],
#  ['local',
# ...
#   'impermeable',
#   'barrier'],
#  ['evidence',
#   'source',
#   'rocks',
#   'excellent',
#   'indicate',
#   'significant',
#   'quantities',
#   'oil',
#   'anticosti',
#   'basin',
#   'gas',
#   'magdalen',
#   'basin'],
#  ['north',
#   'anticosti',
#   'basin',
#   'new',
#   'prospecting',
#   'concepts',
#   'evolving',
#   'based',
#   'new',
#   'knowledge',
#   'called',
#   'hydrothermal',
#   'dolomitization',
#   'associated',
#   'deep',
#   'faults',
#   'basement',
#   'rocks',
#   'continental',
#   'mass'],
#  ['extensive',
#   'network',
#   'faults',
#   'associated',
#   'structural',
#   'deformation',
#   'occurs',
#   'anticosti',
#   'island',
#   'adjacent',
#   'offshore',
#   'regions'],
#  ['depending',
#   'identified',
#   'recoverable',
#   'reserves',
#   'production',
#   'rates',
#   'onshore',
#   'offshore',
#   'regions',
#   'anticosti',
#   'basin',
#   'major',
#   'oil',
#   'producing',
#   'areas'],
#  ['south',
#   'magdalen',
#   'basin',
#   'new',
#   'prospecting',
#   'concepts',
#   'evolving',
#   'modern',
#   'understanding',
#   'called',
#   'salt',
#   'diapirism',
#   'related',
#   'deeply',
#   'buried',
#   'salt',
#   'beds',
#   'similar',
#   'finds',
#   'gulf',
#   'mexico',
#   'southwestern',
#   'iran'],
#  ['deformed',
#   'salt',
#   'beds',
#   'magdalen',
#   'basin',
#   'extensive',
#   'area',
#   'underlying',
#   'approximately',
#   'square',
#   'miles',
#   'nearly',
#   'area',
#   'saudi_arabia',
#   'ghawar',
#   'oil',
#   'field',
#   'alas',
#   'thick',
#   'pay',
#   'zones',
#   'middle_east',
#   'supergiant'],
#  ['despite',
#   'proximity',
#   'industrially',
#   'developed',
#   'regions',
#   'canada',
#   'certainly',
#   'vast',
#   'markets',
#   'united_states',
#   'exploration',
#   'gulf',
#   'st',
#   'lawrence',
#   'region',
#   'frontier',
#   'stage'],
#  ['overstating',
#   'case',
#   'biggest',
#   'best',
#   'oil',
#   'gas',
#   'prospects',
#   'region',
#   'waiting',
#   'explored',
#   'drilled'],
#  ['oil', 'gas'],
#  ['good', 'old', 'days', 'drilling', 'bumps'],
#  ['days', 'col', 'drake', 'oil', 'gas'],
#  ['somebody', 'look', 'right', 'places', 'drill', 'hole', 'ground', 'set'],
#  ['figured',
#   'discovering',
#   'producing',
#   'hydrocarbons',
#   'end',
#   'hubbert',
#   'peak',
#   'going',
#   'lot',
#   'harder',
#   'half',
#   'ride'],
#  ['easy'],
#  ['lose', 'shirt'],
#  ['world', 'oil', 'boom', 'making'],
#  ['worse', 'eye', 'maritime', 'provinces', 'eastern', 'canada'],
#  ['figuratively',
#   'col',
#   'drakes',
#   'coming',
#   'oil',
#   'boom',
#   'eastern',
#   'canada'],
#  ['number',
#   'oil',
#   'exploration',
#   'firms',
#   'heavily',
#   'involved',
#   'anticosti',
#   'magdalen',
#   'basins'],
#  ['conducting',
#   'seismic',
#   'work',
#   'performing',
#   'ground',
#   'mapping',
#   'leasing',
#   'best',
#   'acreage',
#   'prime',
#   'oil',
#   'patch',
#   'drilling',
#   'test',
#   'holes',
#   'yonder',
#   'wildcats',
#   'live',
#   'coin',
#   'phrase'],
#  ['big',
#   'time',
#   'drilling',
#   'starts',
#   'years',
#   'action',
#   'outside',
#   'looking'],
#  ['process',
#   'performing',
#   'diligence',
#   'respect',
#   'companies',
#   'working',
#   'exploring',
#   'gulf',
#   'st',
#   'lawrence'],
#  ['arranging',
#   'visit',
#   'area',
#   'meet',
#   'key',
#   'people',
#   'involved',
#   'largest',
#   'plays'],
#  ['fun', 'going', 'field', 'kick', 'paleozoic', 'rocks'],
#  ['plan',
#   'companies',
#   'best',
#   'positioned',
#   'profit',
#   'new',
#   'exploration',
#   'frontier',
#   'area',
#   'presentation',
#   'agora',
#   'wealth',
#   'symposium',
#   'vancouver',
#   'british',
#   'columbia',
#   'aug'],
#  ['hope'],
#  ['meet', 'byron', 'w.', 'king'],
#  ['editor', 'note', 'dave', 'roberts', 'interview'],
#  ['originally',
#   'going',
#   'run',
#   'interview',
#   'alongside',
#   'ambitious',
#   'long',
#   'form',
#   'piece',
#   'time',
#   'passed',
#   'believe',
#   'time',
#   'passed',
#   'clear',
#   'said',
#   'piece',
#   'indefinitely',
#   'postponed'],
#  ['baby', 'checks', 'calendar', 'days', 'ago', 'unlikely'],
#  ['soon', 'time', 'return'],
#  ['lest', 'older', 'm', 'going', 'ahead', 'run'],
#  ['lots',
#   'good',
#   'stuff',
#   'long',
#   've',
#   'broken',
#   'parts',
#   'publish',
#   'today',
#   'coming',
#   'days'],
#  ['discuss', 'optimism', 'technology', 'open', 'source', 'movement'],
#  ['dave',
#   'roberts',
#   'view',
#   'humans',
#   'essential',
#   'problem',
#   'given',
#   'destruction',
#   've',
#   'wreaked',
#   'continue',
#   'wreak',
#   'planet'],
#  ['alex',
#   'steffen',
#   'philosophically',
#   'differ',
#   'folks',
#   'environmental',
#   'community',
#   'think',
#   'goal',
#   'create',
#   'human',
#   'civilization',
#   'balance',
#   'nature'],
#  ['weigh', 'element', 'heavily'],
#  ['certainly',
#   'happy',
#   'planet',
#   'barren',
#   'human',
#   'life',
#   'spectacularly',
#   'abundant',
#   'biologically'],
#  ['time', 'worthwhile', 'human', 'future', 'ruined', 'planet'],
#  ['real', 'question', 'humans', 'problem', 'problem'],
#  ['william',
#   's.',
#   'burroughs',
#   'quote',
#   'love',
#   'words',
#   'came',
#   'dream',
#   'said',
#   'fully',
#   'understand',
#   'technique'],
#  ['short', 'time', 'nearly', 'wrecked', 'planet'],
#  ['find', 'liberating', 'true'],
#  ['critical',
#   'question',
#   'matter',
#   'morality',
#   'religious',
#   'virtues',
#   'human',
#   'beings',
#   'fallen'],
#  ['matter', 'ecological', 'sin'],
#  ['question', 'intelligence', 'design', 'imagination'],
#  ['question', 'seeing', 'truly', 'acting', 'accordingly'],
#  ['way', 'problem', 'solve', 'tragedy', 'human', 'nature'],
#  ['build',
#   'moral',
#   'construct',
#   'places',
#   'human',
#   'beings',
#   'opposition',
#   'planet',
#   'lose',
#   'future'],
#  ['left', 'longing', 'mythological', 'noble', 'savage', 'kind', 'world'],
#  ['dr'],
#  ['right'],
#  ['worth',
#   'emphasizing',
#   'vision',
#   'future',
#   'structurally',
#   'impossible',
#   'moral'],
#  ['virtue'],
#  ['like',
#   'running',
#   'jumping',
#   'building',
#   'great',
#   'fly',
#   'practical',
#   'result',
#   'end',
#   'squashed',
#   'pavement'],
#  ['makes', 'irrelevant'],
#  ['absolutely'],
#  ['idea',
#   'model',
#   'human',
#   'civilization',
#   'past',
#   'okay',
#   'intellectually',
#   'bankrupt'],
#  ['past',
#   'civilization',
#   'support',
#   'billions',
#   'today',
#   'sustainable',
#   'way'],
#  ['need', 'invent', 'sustainable', 'life', 'scratch'],
#  ['point',
#   'environmentalists',
#   'suggest',
#   'proper',
#   'goal',
#   'wear',
#   'furs',
#   'shoot',
#   'deer',
#   'longbows',
#   'irrelevant',
#   'planning',
#   'future'],
#  ['terrible',
#   'thing',
#   'midst',
#   'making',
#   'vastly',
#   'important',
#   'decisions',
#   'fate',
#   'planet',
#   'environmentalists',
#   'need',
#   'heard',
#   'debate'],
#  ['moving', 'forward', 'mean'],
#  ['need', 'discover'],
#  ['need',
#   'invent',
#   'vision',
#   'future',
#   'prosperous',
#   'ecological',
#   'attractive',
#   'sustainable',
#   'bright',
#   'green'],
#  ['need', 'present', 'optimistic', 'future', 'worth', 'fighting'],
#  ['job', 'environmental', 'movement'],
#  ['dr',
#   'given',
#   'human',
#   'irrationality',
#   'territorialism',
#   'evidence',
#   'past',
#   'capable',
#   'long_term',
#   'rational',
#   'planning',
#   'better',
#   'future',
#   'capable',
#   'individuals',
#   'conceiving',
#   'capable',
#   'persuading',
#   'large',
#   'numbers',
#   'people'],
#  ['democracy'],
#  ['human', 'rights'],
#  ['reason'],
#  ['ve', 'worked'],
#  ['best', 'evidence'],
#  ['look', 'human', 'history', 'pretty', 'shabby', 'ride', 'beginning'],
#  ['joyce', 'said', 'history', 'nightmare', 'trying', 'awake'],
#  ['enlightenment', 'woke'],
#  ['forget', 'progress', 'years'],
#  ['yes',
#   'terrible',
#   'tragedies',
#   'genocides',
#   'awful',
#   'disasters',
#   'children',
#   'dying',
#   'needlessly',
#   'hunger',
#   'preventable',
#   'disease',
#   'said',
#   'good',
#   'things'],
#  ['people',
#   'planet',
#   'living',
#   'lives',
#   'relative',
#   'prosperity',
#   'relative',
#   'freedom',
#   'pursuing',
#   'ideas',
#   'happiness'],
#  ['feudalism', 'mass', 'murder', 'slavery', 'ignorance', 'winning'],
#  ['percentage',
#   'human',
#   'beings',
#   'absolute',
#   'poverty',
#   'going',
#   'long',
#   'time',
#   'job',
#   'right',
#   'eventually',
#   'wind'],
#  ['people', 'live', 'democracies'],
#  ['fewer', 'fewer', 'people', 'persecuted', 'politically'],
#  ['people', 'accept', 'theory', 'science', 'reason'],
#  ['fact',
#   'backlash',
#   'radical',
#   'fundamentalists',
#   'stripes',
#   'sign',
#   'winning'],
#  ['extremists',
#   'pouring',
#   'backwoods',
#   'afghanistan',
#   'blow',
#   'buildings',
#   'u.s',
#   'feel',
#   'like',
#   'values',
#   'beating',
#   'theirs'],
#  ['design',
#   'human',
#   'civilization',
#   'material',
#   'civilization',
#   'uses',
#   'far',
#   'fewer',
#   'resources',
#   'delivers',
#   'far',
#   'prosperity',
#   'far',
#   'sustainable',
#   've',
#   'imagined'],
#  ['dr',
#   'sounds',
#   'like',
#   'variant',
#   'francis',
#   'fukuyama',
#   'end',
#   'history',
#   'idea',
#   'democratic',
#   'capitalism',
#   'basically',
#   'right',
#   'remains',
#   'rest',
#   'world',
#   'coming'],
#  ['view',
#   'great',
#   'currency',
#   '90s',
#   'hit',
#   'bit',
#   'rough',
#   'patch',
#   'lot',
#   'countries',
#   've',
#   'attempted',
#   'spread',
#   'shall',
#   'intransigent',
#   'accepting',
#   'benefits'],
#  ['think', 'fair', 'vision', 'version'],
#  ['believe', 'millenarianism'],
#  ['point', 'humanity', 'going', 'stop'],
#  ['friend', 'bruce', 'sterling', 'puts', 'future', 'process', 'theme', 'park'],
#  ['said', 'think', 'problems', 'know', 'solve'],
#  ['getting', 'better', 'solving', 'problems'],
#  ['grasp', 'solve', 'number', 'problems', 'vexed', 'beginning'],
#  ['solving',
#   'problems',
#   'mean',
#   'going',
#   'suddenly',
#   'run',
#   'problems',
#   'going'],
#  ['prize',
#   'solving',
#   'problems',
#   'face',
#   'interesting',
#   'problems',
#   'solve',
#   'future'],
#  ['enormous', 'threats', 'loom'],
#  ['ve',
#   'massive',
#   'damage',
#   'planet',
#   'probably',
#   'going',
#   'managing',
#   'blowback',
#   'lifetimes'],
#  ['asteroid', 'smash', 'civilization', 'bits'],
#  ['superflu', 'come', 'kill'],
#  ['people', 'weird'],
#  ['strange', 'things', 'happen'],
#  ['wobbling'],
#  ['undoubtedly', 'huge', 'setbacks', 'seeing', 'huge', 'setbacks'],
#  ['dr'],
#  ['era', 'huge', 'setbacks', '00s'],
#  ['yes', 'important', 'big', 'picture', 'mind'],
#  ['going',
#   'fast',
#   'ought',
#   'world',
#   'peace',
#   'justice',
#   'prosperity',
#   'sustainability'],
#  ['moving', 'direction'],
#  ['clearly', 'yes'],
#  ['afford', 'luxury', 'getting', 'discouraged', 'setbacks'],
#  ['think', 'optimism', 'prerequisite', 'human', 'survival'],
#  ['dr', 'lots', 'folks', 'wonder', 'plan', 'future', 'like'],
#  ['strengths', 'democracy', 'lack', 'central', 'planning'],
#  ['instead',
#   'emergent',
#   'intelligence',
#   'distributed',
#   'power',
#   'distributed',
#   'decision',
#   'making',
#   'structural',
#   'resistance',
#   'concentrations',
#   'wealth',
#   'power'],
#  ['pressure',
#   'want',
#   'concentrate',
#   'wealth',
#   'power',
#   've',
#   'fairly',
#   'good',
#   'job',
#   'country',
#   'distributing',
#   'power',
#   'result',
#   'sort',
#   'fraught',
#   'stumbling',
#   'halting',
#   'movement',
#   'right',
#   'direction'],
#  ['theme',
#   'distributed',
#   'collaborative',
#   'decision',
#   'making',
#   'running',
#   'lot',
#   'envision',
#   'positive',
#   'future',
#   'lot',
#   'things',
#   'write'],
#  ['address', 'idea', 'regard', 'technology'],
#  ['technology',
#   'famous',
#   'bugaboo',
#   'environmentalists',
#   'written',
#   'intrinsically',
#   'harmful'],
#  ['anti', 'technology', 'day', 'age', 'anti', 'environmental'],
#  ['positive', 'future', 'exists', 'vastly', 'improved', 'technology'],
#  ['criticism', 'hear', 'relying', 'techno', 'fix', 'artificial', 'solution'],
#  ['techno', 'fixes', 'improved', 'lives'],
#  ['fact',
#   'beat',
#   'probabilities',
#   'die',
#   'childhood',
#   'disease',
#   'directly',
#   'attributable',
#   'technology',
#   'fact',
#   'starve',
#   'years',
#   'directly',
#   'attributable',
#   'technology',
#   'fact',
#   'know',
#   'planet',
#   'worried',
#   'things',
#   'like',
#   'climate_change',
#   'directly',
#   'attributable',
#   'technology'],
#  ['wobbled', 'trees', 'grabbed', 'burning', 'branch', 've', 'technology'],
#  ['inventing', 'better', 'tools', 'human'],
#  ['comes',
#   'technology',
#   'questions',
#   'worth',
#   'asking',
#   'number',
#   'sure',
#   'technologies',
#   'embrace',
#   'good',
#   'ones'],
#  ['number', 'innovate', 'quickly'],
#  ['terms', 'm', 'huge', 'fan', 'democratic', 'control', 'technology'],
#  ['good', 'idea', 'better', 'process'],
#  ['gets', 'better', 'results'],
#  ['collaboration',
#   'distributed',
#   'control',
#   'transparency',
#   'democratic',
#   'debate',
#   'public',
#   'access',
#   'basic',
#   'research',
#   'things',
#   'engines',
#   'innovation',
#   'yes',
#   'best',
#   'checks',
#   'catastrophic',
#   'failures'],
#  ['powerful',
#   'attributes',
#   'approaches',
#   'like',
#   'open',
#   'source',
#   'software',
#   'example',
#   'develop',
#   'technology',
#   'public',
#   'increased',
#   'ability',
#   'apply',
#   'precautionary',
#   'principle'],
#  ['increased', 'ability', 'look', 'ahead', 'problems', 'create'],
#  ['dr', 'increased', 'ability', 'come'],
#  ['actually'],
#  ['handful',
#   'people',
#   'planet',
#   'look',
#   'inside',
#   'operating',
#   'code',
#   'microsoft',
#   'windows'],
#  ['disaster', 'waiting', 'happen', 'people', 'know'],
#  ['contrast',
#   'like',
#   'linux',
#   'tens',
#   'thousands',
#   'people',
#   'routinely',
#   'check',
#   'code',
#   'discuss',
#   'different',
#   'ways',
#   'changing'],
#  ['extrapolate', 'like', 'power', 'system'],
#  ['deeply',
#   'secretive',
#   'centralized',
#   'power',
#   'system',
#   'like',
#   'nuclear_power',
#   'difficult',
#   'eyes',
#   'watching',
#   'problems',
#   'thing',
#   'violation',
#   'law'],
#  ['distributed',
#   'power',
#   'grid',
#   'like',
#   'san_francisco',
#   'based',
#   'solar_panels',
#   'tied',
#   'utility',
#   'system',
#   'ability',
#   'look',
#   'potential',
#   'problems',
#   'ways',
#   'system',
#   'brittle'],
#  ['safer', 'system', 'open'],
#  ['dr',
#   'theme',
#   'ties',
#   'democratic',
#   'culture',
#   'open',
#   'source',
#   'technology',
#   'distributed',
#   'power',
#   'systems'],
#  ['feature', 'systems', 'ability', 'degrade', 'gracefully'],
#  ['modularity',
#   'allows',
#   'individual',
#   'pieces',
#   'fail',
#   'broad',
#   'systemic',
#   'failure',
#   'contrast',
#   'nuclear_power',
#   'piece',
#   'failure',
#   'lead',
#   'catastrophe'],
#  ['read',
#   'article',
#   'today',
#   'somebody',
#   'claimed',
#   'costs',
#   'chernobyl',
#   'meltdown',
#   'greater',
#   'value',
#   'energy',
#   'provided',
#   'soviet',
#   'union',
#   'nuclear_power',
#   'existence'],
#  ['yes', 'improving', 'reliability', 'system', 'openness', 'real', 'value'],
#  ['mind',
#   'important',
#   'benefit',
#   'open',
#   'collaborative',
#   'approaches',
#   'innovate',
#   'quickly'],
#  ['right', 'entering', 'period', 'like', 'tech', 'bloom'],
#  ['lot',
#   'people',
#   'think',
#   'tech',
#   'boom',
#   'ended',
#   'technological',
#   'innovation',
#   'went',
#   'flat'],
#  ['exact', 'opposite', 'true'],
#  ['seeing', 'people', 'inventing', 'useful', 'things', 'moment', 'seen'],
#  ['explosion', 'innovation', 'happening'],
#  ['big', 'reason', 'people', 'inventing', 'sharing', 'inventions', 'freely'],
#  ['matter', 'environment'],
#  ['destruction', 'caused', 'american', 'consumerism', 'accidental'],
#  ['americans',
#   've',
#   'heard',
#   'percent',
#   'planet',
#   'population',
#   'use',
#   'percent',
#   'resources',
#   'energy',
#   'sources'],
#  ['economy', 'generates', 'nearly', 'pounds', 'waste', 'person', 'year'],
#  ['amory',
#   'lovins',
#   'crowd',
#   'found',
#   'achieve',
#   'better',
#   'percent',
#   'efficiency',
#   'way',
#   'use',
#   'materials'],
#  ['rest', 'pure', 'waste'],
#  ['william',
#   'mcdonough',
#   'says',
#   'people',
#   'garbage',
#   'cans',
#   'tip',
#   'material',
#   'iceberg'],
#  ['society', 'major', 'product', 'wealth', 'waste'],
#  ['set', 'design', 'system', 'works', 'like'],
#  ['accident', 'history'],
#  ['design',
#   'systems',
#   'create',
#   'minute',
#   'fraction',
#   'waste',
#   'deliver',
#   'better',
#   'products',
#   'save',
#   'money',
#   'competitive',
#   'process'],
#  ['break', 'connection', 'wealth', 'waste'],
#  ['think'],
#  ['implications',
#   'huge',
#   'thinking',
#   'wealth',
#   'causes',
#   'environmental',
#   'destruction'],
#  ['efficient',
#   'main',
#   'thing',
#   'stopping',
#   'rich',
#   'ecological',
#   'footprint',
#   'innovation'],
#  ['nation', 'earth', 'opportunity', 'innovate'],
#  ['united_states',
#   'richest',
#   'nation',
#   'planet',
#   'home',
#   'largest',
#   'educated',
#   'population',
#   'scientists',
#   'designers',
#   'engineers',
#   'biggest',
#   'universities',
#   'charitable',
#   'foundations',
#   'research',
#   'labs'],
#  ['anybody', 'money', 'brainpower', 'create', 'future', 'green', 'bright'],
#  ...]

# %%
def get_wc(word, data):
    wc = 0
    for word_list in data:
        for w in word_list:
            if w == word:
                wc += 1
    return wc

# %%
def get_adjacent_words(word, data):
    '''
    Data to be provided as a list of lists.
    '''
    after = []
    before = []

    for word_list in data:
        for i, w in enumerate(word_list):
            if w == word:
                if i < len(word_list) - 1:
                    after.append(word_list[i+1])
                if i > 0:
                    before.append(word_list[i-1])
    
    return pd.Series(before).value_counts(), pd.Series(after).value_counts()

# %%
before, after = get_adjacent_words('environmental', env_small.tokens)

# %%
before, after = get_adjacent_words('environmental', dfs[0].sample(500).sents.sum())

# %%
for i in range(17):
    before, after = get_adjacent_words('environmental', dfs[i].sample(500).sents.sum())
    
    print("Year:", 2005 + i)
    print("Rank:", after.index.get_loc('justice'))
    print("Freqeuncy:", after.loc['justice'])
    print("Percentage:", 100 * after.loc['justice'] / after.sum())
    print("")
# Out:
# Year: 2005
# Rank: 32
# Freqeuncy: 4
# Percentage: 0.6791171477079796
#
# Year: 2006
# Rank: 32
# Freqeuncy: 3
# Percentage: 0.746268656716418
#
# Year: 2007
# Rank: 33
# Freqeuncy: 3
# Percentage: 0.7109004739336493
#
# Year: 2008
# Rank: 5
# Freqeuncy: 6
# Percentage: 2.3622047244094486
#
# Year: 2009
# Rank: 56
# Freqeuncy: 2
# Percentage: 0.5524861878453039
#
# Year: 2010
# Rank: 28
# Freqeuncy: 5
# Percentage: 1.152073732718894
#
# Year: 2011
# Rank: 12
# Freqeuncy: 8
# Percentage: 1.5238095238095237
#
# Year: 2012
# Rank: 71
# Freqeuncy: 1
# Percentage: 0.3546099290780142
#
# Year: 2013
# Rank: 1
# Freqeuncy: 13
# Percentage: 3.812316715542522
#
# Year: 2014
# Rank: 1
# Freqeuncy: 21
# Percentage: 4.805491990846682
#
# Year: 2015
# Rank: 0
# Freqeuncy: 47
# Percentage: 9.021113243761997
#
# Year: 2016
# Rank: 1
# Freqeuncy: 25
# Percentage: 4.520795660036167
#
# Year: 2017
# Rank: 0
# Freqeuncy: 58
# Percentage: 7.561929595827901
#
# Year: 2018
# Rank: 0
# Freqeuncy: 30
# Percentage: 3.8412291933418694
#
# Year: 2019
# Rank: 0
# Freqeuncy: 73
# Percentage: 10.5643994211288
#
# Year: 2020
# Rank: 0
# Freqeuncy: 162
# Percentage: 16.998950682056662
#
# Year: 2021
# Rank: 0
# Freqeuncy: 202
# Percentage: 16.946308724832214

# %%
for i in range(17):
    word1='environmental'
    word2='racism'
    
    before, after = get_adjacent_words(word1, dfs[i].sample(500).sents.sum())
    
    try:
        rank = after.index.get_loc(word2)
        freq = after.loc[word2]
        pct = 100 * after.loc[word2] / after.sum()
    except KeyError:
        rank = np.nan
        freq = 0
        pct = 0
    
    print("Year:", 2005 + i)
    print("Rank:", rank)
    print("Freqeuncy:", freq)
    print("Percentage:", pct)
    print("")
# Out:
# Year: 2005
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2006
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2007
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2008
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2009
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2010
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2011
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2012
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2013
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2014
# Rank: 55
# Freqeuncy: 2
# Percentage: 0.4672897196261682
#
# Year: 2015
# Rank: 14
# Freqeuncy: 7
# Percentage: 1.2089810017271156
#
# Year: 2016
# Rank: 27
# Freqeuncy: 5
# Percentage: 0.9107468123861566
#
# Year: 2017
# Rank: 43
# Freqeuncy: 3
# Percentage: 0.3931847968545216
#
# Year: 2018
# Rank: nan
# Freqeuncy: 0
# Percentage: 0
#
# Year: 2019
# Rank: 40
# Freqeuncy: 5
# Percentage: 0.6426735218508998
#
# Year: 2020
# Rank: 40
# Freqeuncy: 5
# Percentage: 0.5500550055005501
#
# Year: 2021
# Rank: 13
# Freqeuncy: 16
# Percentage: 1.2759170653907497

# %%
for i in range(17):
    print(get_wc('extraction', dfs[i].sample(500).sents.sum()))
# Out:
# 45
# 23
# 18
# 6
# 28
# 16
# 53
# 30
# 34
# 39
# 65
# 68
# 72
# 52
# 47
# 79
# 68

# %%
after.sum()
# Out:
# 621
